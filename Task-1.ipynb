# %%
import tkinter as tk
from tkinter import simpledialog, messagebox

#function to implement add_task functionality
def add_task():
    global listbox_tasks, entry_task
    task = entry_task.get()
    if task:
        listbox_tasks.insert(tk.END, task)
        entry_task.delete(0, tk.END)
    else:
        messagebox.showwarning("Warning", "Please enter a task.")

#function to implement delete_task functionality
def delete_task():
    global listbox_tasks
    try:
        index = listbox_tasks.curselection()[0]
        listbox_tasks.delete(index)
    except IndexError:
        messagebox.showwarning("Warning", "Please select a task to delete.")

#function to implement edit_task functionality
def edit_task():
    global listbox_tasks
    try:
        index = listbox_tasks.curselection()[0]
        old_task = listbox_tasks.get(index)
        new_task = simpledialog.askstring("Edit Task", "Edit the selected task:", initialvalue=old_task)
        if new_task:
            listbox_tasks.delete(index)
            listbox_tasks.insert(index, new_task)
    except IndexError:
        messagebox.showwarning("Warning", "Please select a task to edit.")

#function to implement mark_as_done functionality
def mark_as_done():
    global listbox_tasks
    try:
        index = listbox_tasks.curselection()[0]
        task = listbox_tasks.get(index)
        updated_task = task + " (Done)"
        listbox_tasks.delete(index)
        listbox_tasks.insert(index, updated_task)
    except:
        messagebox.showwarning("Warning", "Please select a task to mark as done.")


def main():
    global listbox_tasks, entry_task
    root = tk.Tk()
    root.title("CodSoft Python Programming Task-1")
   
    ourMessage ='To-Do List'
    messageVar = tk.Message(root, text = ourMessage, width=700, font=("Times New Roman", 43, "bold"))
    messageVar.config(bg='lightgreen')
    messageVar.pack(pady=10, padx=0)

    frame_tasks = tk.Frame(root)
    frame_tasks.pack(pady=10)
   
    listbox_tasks = tk.Listbox(frame_tasks, width=50, height=10, selectbackground="green")
    listbox_tasks.pack(side=tk.LEFT, fill=tk.BOTH)

    scrollbar_tasks = tk.Scrollbar(frame_tasks)
    scrollbar_tasks.pack(side=tk.RIGHT, fill=tk.BOTH)

    listbox_tasks.config(yscrollcommand=scrollbar_tasks.set)
    scrollbar_tasks.config(command=listbox_tasks.yview)

    entry_task = tk.Entry(root, width=50)
    entry_task.pack(pady=10)

    button_add_task = tk.Button(root, text="Add Task", command=add_task)
    button_add_task.pack(side=tk.LEFT, padx=7, pady=5)

    button_delete_task = tk.Button(root, text="Delete Task", command=delete_task)
    button_delete_task.pack(side=tk.LEFT, padx=5, pady=5)

    button_edit_task = tk.Button(root, text="Edit Task", command=edit_task)
    button_edit_task.pack(side=tk.LEFT, padx=5, pady=5)
   
    mark_done_button = tk.Button(root, text="Mark as Done", command=mark_as_done)
    mark_done_button.pack(side=tk.LEFT, padx=5, pady=5)

    root.mainloop()

if __name__ == "__main__":
    main()
